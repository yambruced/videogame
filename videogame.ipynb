# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
V = pd.read_csv("videogame.csv")

# %%
V.head()
# Out:
#    Rank                           Name                      basename  \
# 0     1                     Wii Sports                    wii-sports
# 1     2              Super Mario Bros.              super-mario-bros
# 2     3                 Mario Kart Wii                mario-kart-wii
# 3     4  PlayerUnknown's Battlegrounds  playerunknowns-battlegrounds
# 4     5              Wii Sports Resort             wii-sports-resort
#
#       Genre ESRB_Rating Platform         Publisher         Developer  \
# 0    Sports           E      Wii          Nintendo      Nintendo EAD
# 1  Platform         NaN      NES          Nintendo      Nintendo EAD
# 2    Racing           E      Wii          Nintendo      Nintendo EAD
# 3   Shooter         NaN       PC  PUBG Corporation  PUBG Corporation
# 4    Sports           E      Wii          Nintendo      Nintendo EAD
#
#    VGChartz_Score  Critic_Score  \
# 0             NaN           7.7
# 1             NaN          10.0
# ...

# %%
V.tail()
# Out:
#         Rank         Name     basename             Genre ESRB_Rating Platform  \
# 55787  55788  Indivisible  indivisible      Role-Playing         NaN       PC
# 55788  55789   Lost Ember   lost-amber         Adventure          RP       PC
# 55789  55790   Lost Ember   lost-amber         Adventure          RP      PS4
# 55790  55791   Lost Ember   lost-amber         Adventure          RP     XOne
# 55791  55792   Falcon Age   falcon-age  Action-Adventure         NaN      PS4
#
#              Publisher        Developer  VGChartz_Score  Critic_Score  \
# 55787        505 Games   Lab Zero Games             NaN           NaN
# 55788  Mooneye Studios  Mooneye Studios             NaN           NaN
# 55789  Mooneye Studios  Mooneye Studios             NaN           NaN
# 55790  Mooneye Studios  Mooneye Studios             NaN           NaN
# 55791          Unknown  Outerloop Games             NaN           NaN
#
# ...

# %%
V.dtypes
# Out:
# Rank                int64
# Name               object
# basename           object
# Genre              object
# ESRB_Rating        object
# Platform           object
# Publisher          object
# Developer          object
# VGChartz_Score    float64
# Critic_Score      float64
# User_Score        float64
# Total_Shipped     float64
# Global_Sales      float64
# NA_Sales          float64
# PAL_Sales         float64
# JP_Sales          float64
# Other_Sales       float64
# Year              float64
# Last_Update        object
# url                object
# status              int64
# Vgchartzscore     float64
# img_url            object
# dtype: object

# %%
V.set_index("Name",inplace=True)

# %%
V.head()
# Out:
#                                Rank                      basename     Genre  \
# Name
# Wii Sports                        1                    wii-sports    Sports
# Super Mario Bros.                 2              super-mario-bros  Platform
# Mario Kart Wii                    3                mario-kart-wii    Racing
# PlayerUnknown's Battlegrounds     4  playerunknowns-battlegrounds   Shooter
# Wii Sports Resort                 5             wii-sports-resort    Sports
#
#                               ESRB_Rating Platform         Publisher  \
# Name
# Wii Sports                              E      Wii          Nintendo
# Super Mario Bros.                     NaN      NES          Nintendo
# Mario Kart Wii                          E      Wii          Nintendo
# PlayerUnknown's Battlegrounds         NaN       PC  PUBG Corporation
# Wii Sports Resort                       E      Wii          Nintendo
#
# ...

# %%
V.dtypes
# Out:
# Rank                int64
# basename           object
# Genre              object
# ESRB_Rating        object
# Platform           object
# Publisher          object
# Developer          object
# VGChartz_Score    float64
# Critic_Score      float64
# User_Score        float64
# Total_Shipped     float64
# Global_Sales      float64
# NA_Sales          float64
# PAL_Sales         float64
# JP_Sales          float64
# Other_Sales       float64
# Year              float64
# Last_Update        object
# url                object
# status              int64
# Vgchartzscore     float64
# img_url            object
# dtype: object

# %%
V[V['ESRB_Rating'] == 'M'].sort_values('NA_Sales',ascending=False).tail(5)
# Out:
#                               Rank                   basename         Genre  \
# Name
# Wasteland 2: Director's Cut  55649  wasteland-2-directors-cut      Strategy
# XBlaze Lost: Memories        55722       xblaze-lost-memories  Visual Novel
# YIIK: A Postmodern RPG       55755      yiik-a-postmodern-rpg  Role-Playing
# YIIK: A Postmodern RPG       55756      yiik-a-postmodern-rpg  Role-Playing
# Zombeer                      55775                    zombeer        Action
#
#                             ESRB_Rating Platform             Publisher  \
# Name
# Wasteland 2: Director's Cut           M       NS  inXile Entertainment
# XBlaze Lost: Memories                 M       PC           Aksys Games
# YIIK: A Postmodern RPG                M       NS          Ysbryd Games
# YIIK: A Postmodern RPG                M      PS4          Ysbryd Games
# Zombeer                               M     WiiU               Unknown
#
# ...

# %%
V.set_index('Developer',inplace=True)

# %%
V.head()
# Out:
#                   Rank                      basename     Genre ESRB_Rating  \
# Developer
# Nintendo EAD         1                    wii-sports    Sports           E
# Nintendo EAD         2              super-mario-bros  Platform         NaN
# Nintendo EAD         3                mario-kart-wii    Racing           E
# PUBG Corporation     4  playerunknowns-battlegrounds   Shooter         NaN
# Nintendo EAD         5             wii-sports-resort    Sports           E
#
#                  Platform         Publisher  VGChartz_Score  Critic_Score  \
# Developer
# Nintendo EAD          Wii          Nintendo             NaN           7.7
# Nintendo EAD          NES          Nintendo             NaN          10.0
# Nintendo EAD          Wii          Nintendo             NaN           8.2
# PUBG Corporation       PC  PUBG Corporation             NaN           NaN
# Nintendo EAD          Wii          Nintendo             NaN           8.0
#
# ...

# %% [markdown]
# # Average sales based on genre

# %%
V.groupby('Genre')['Total_Shipped'].mean().head(10)
# Out:
# Genre
# Action              1.220675
# Action-Adventure    0.992099
# Adventure           1.101034
# Board Game               NaN
# Education           0.165000
# Fighting            2.436885
# MMO                 2.308333
# Misc                2.064765
# Music               1.170000
# Party               3.913333
# Name: Total_Shipped, dtype: float64

# %% [markdown]
# # Top 10 Best Selling videogame Genres

# %%
plt.figure(figsize=(8,6))
plt.title('Top 10 Game Genres Average Shipped')
plt.xlabel('Total Shipped')
V.groupby('Genre')['Total_Shipped'].mean().sort_values(ascending=False).head(10).plot.barh(alpha=.7)

# %%
import folium

# %%
map = folium.Map(location=(40.7128,-74.0060),zoom_start=10)

for each in Nintendo.iterrows():
    marker = folium.CircleMarker(location=[each[1]['Latitude'],each[1]['Longitude']],
                          tooltip=each[1]['Genre'],radius=3,color='red',opacity=.5,fill_color='red',)
    marker.add_to(map)

display(map)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-a4e26bdc1fe1> in <module>
#       1 map = folium.Map(location=(40.7128,-74.0060),zoom_start=10)
#       2
# ----> 3 for each in Nintendo.iterrows():
#       4     marker = folium.CircleMarker(location=[each[1]['Latitude'],each[1]['Longitude']],
#       5                           tooltip=each[1]['Genre'],radius=3,color='red',opacity=.5,fill_color='red',)
#
# NameError: name 'Nintendo' is not defined

# %%
V[V['Genre'] == 'Action'].sort_values('Platform',ascending=False).head()

# %% [markdown]
# # Grand Theft Auto V information

# %%
V[V['basename'] == 'grand-theft-auto-v'].sort_values('Total_Shipped',ascending=False).head()

# %% [markdown]
# # Top 10 Systems with the most games sold

# %%
plt.figure(figsize=(8,6))
plt.title("Gaming Systems with the most game sales worldwide")
plt.xlabel('Global Sales')
V.groupby('Platform')['Global_Sales'].mean().sort_values(ascending=False).head(20).plot.barh(alpha=.7)

# %% [markdown]
# # Top 10 Selling Videogames of all time

# %%
plt.figure(figsize=(8,6))
plt.title("Top Selling Games of all time")
plt.xlabel('Sales Worldwide')
V.groupby('basename')['Global_Sales'].mean().sort_values(ascending=False).head(10).plot.barh(alpha=.7)

# %% [markdown]
# # Top 10 best selling publishers

# %%
plt.figure(figsize=(8,6))
plt.title("Top 10 Best Selling Videogame Publishers")
plt.xlabel('Sales')
V.groupby('Publisher')['Global_Sales'].mean().sort_values(ascending=False).head(10).plot.barh(alpha=.7)

# %% [markdown]
# # Scatter Plot

# %%
plt.figure(figsize=(8,6))
plt.title("Total Games Shipped\nfrom 1982 to 2020")
plt.xlabel('Year')
plt.ylabel('Total Shipped in Millions')
plt.scatter(x=V['Year'],y=V['Total_Shipped'],alpha=.7)

# %%
plt.figure(figsize=(8,6))
plt.title("The Global Sales of videogames\nfrom 1970 to 2020")
plt.xlabel('Year')
plt.ylabel('Global Sales in Millions')
plt.scatter(x=V['Year'],y=V['Global_Sales'],alpha=.7)

# %% [markdown]
# # Average Global Sales

# %%
V.groupby('Year')['Global_Sales'].mean().head(49)
# Out:
# Year
# 1970.0    0.116000
# 1973.0         NaN
# 1975.0         NaN
# 1977.0    0.833333
# 1978.0    0.687778
# 1979.0    0.310000
# 1980.0    0.430000
# 1981.0    1.498571
# 1982.0    0.775870
# 1983.0    0.612973
# 1984.0    0.485000
# 1985.0    0.547500
# 1986.0    0.864167
# 1987.0    0.798571
# 1988.0    0.793636
# 1989.0    1.143750
# 1990.0    1.295714
# 1991.0    0.301429
# 1992.0    0.425200
# 1993.0    0.477872
# 1994.0    0.380101
# 1995.0    0.336957
# 1996.0    0.387321
# 1997.0    0.509209
# 1998.0    0.510340
# 1999.0    0.531239
# 2000.0    0.440317
# 2001.0    0.466286
# 2002.0    0.380035
# 2003.0    0.383321
# 2004.0    0.376787
# 2005.0    0.326216
# 2006.0    0.251046
# 2007.0    0.349939
# 2008.0    0.343690
# 2009.0    0.298557
# 2010.0    0.338289
# 2011.0    0.370911
# 2012.0    0.418569
# 2013.0    0.537175
# 2014.0    0.469691
# 2015.0    0.386486
# 2016.0    0.344286
# 2017.0    0.293324
# 2018.0    0.248745
# 2019.0    0.078065
# 2020.0    0.118519
# ...

# %%
plt.style.use('ggplot')
data = pd.DataFrame({"year" : [2015,2016,2017,2018,2019],
                     "count" :[0.386486,0.344286,0.293324,0.248745,0.078065] })
ax = data.plot(x="year",y="count",linestyle='dashed',marker='o',alpha=.6)
plt.ylabel('Global Sales')
plt.xlabel('Year')
ax.locator_params(integer=True)
plt.title("Average Videogame Global\nSales in the last five years")
plt.tight_layout()
plt.show()
